# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.ExcelFile('TakenMind-Python-Analytics-Problem-case-study-1-1.xlsx')

# %%
df_left = df.parse('Employees who have left')
df_exist = df.parse('Existing employees')

# %%
df_left.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       1                0.38             0.53               2
# 1       2                0.80             0.86               5
# 2       3                0.11             0.88               7
# 3       4                0.72             0.87               5
# 4       5                0.37             0.52               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   157                   3              0
# 1                   262                   6              0
# 2                   272                   4              0
# 3                   223                   5              0
# 4                   159                   3              0
#
#    promotion_last_5years   dept  salary
# 0                      0  sales     low
# 1                      0  sales  medium
# 2                      0  sales  medium
# 3                      0  sales     low
# ...

# %%
df_exist.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0    2001                0.58             0.74               4
# 1    2002                0.82             0.67               2
# 2    2003                0.45             0.69               5
# 3    2004                0.78             0.82               5
# 4    2005                0.49             0.60               3
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   215                   3              0
# 1                   202                   3              0
# 2                   193                   3              0
# 3                   247                   3              0
# 4                   214                   2              0
#
#    promotion_last_5years   dept salary
# 0                      0  sales    low
# 1                      0  sales    low
# 2                      0  sales    low
# 3                      0  sales    low
# ...

# %%
df_left.isnull().sum()
# Out:
# Emp ID                   0
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# promotion_last_5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
df_exist.isnull().sum()
# Out:
# Emp ID                   0
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# promotion_last_5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
#looking at the salary distribution of employee that left
fig1 = sns.countplot(df_left['salary']).get_figure().savefig('left salary dist.png')
plt.title('Salary distribution of employees that left')
plt.xlabel('salary')
plt.ylabel('No.of employees')
plt.show()

# %%
#looking at the salary distribution of employee that exist
fig2 = sns.countplot(df_exist['salary']).get_figure().savefig('exist salary dist.png')
plt.title('Salary distribution of employees that exist')
plt.xlabel('salary')
plt.ylabel('No.of employees')
plt.show()

# %% [raw]
# here we can clearly see that although the both the employees who left as well as exist has a large portion in the low salary category but the number in the medium and high salary category is more among the existing employees

# %%
#looking at the departments of employees that left
plt.figure(figsize=(10,9))
sns.countplot(df_left['dept']).get_figure().savefig('left dept dist.png')
plt.title('department distribution of employees that left')
plt.xlabel('department')
plt.ylabel('No.of employees')
plt.show()

# %%
#looking at the departments of employees that exist
plt.figure(figsize=(10,9))
sns.countplot(df_exist['dept']).get_figure().savefig('exist dept dist.png')
plt.title('department distribution of employees that exist')
plt.xlabel('department')
plt.ylabel('No.of employees')
plt.show()

# %% [raw]
# After looking at both the graph we can see there is not much difference in either. So this might not be a problem.

# %%
#looking at the promotion of employees that left in last 5 years
plt.figure(figsize=(10,9))
sns.countplot(df_left['promotion_last_5years']).get_figure().savefig('left promo dist.png')
plt.title('distribution of promotion of employees that left')
plt.xlabel('No. of promotions')
plt.ylabel('No.of employees')
plt.show()

# %%
#looking at the promotion of employees that exist in last 5 years
plt.figure(figsize=(10,9))
sns.countplot(df_exist['promotion_last_5years']).get_figure().savefig('exist promo dist.png')
plt.title('distribution of promotion of employees that exist')
plt.xlabel('No. of promotions')
plt.ylabel('No.of employees')
plt.show()

# %% [raw]
# again after comparing both the graphs this might not be the reason

# %%
#looking at the work accidents encoutered by the employees that left
plt.figure(figsize=(10,9))
sns.countplot(df_left['Work_accident']).get_figure().savefig('left accident dist.png')
plt.title('distribution of work accidents encountered by the employees that left')
plt.xlabel('No. of accidents')
plt.ylabel('No.of employees')
plt.show()

# %%
#looking at the work accidents encoutered by the employees that exist
plt.figure(figsize=(10,9))
sns.countplot(df_exist['Work_accident']).get_figure().savefig('exist accident dist.png')
plt.title('distribution of work accidents encountered by the employees that exist')
plt.xlabel('No. of accidents')
plt.ylabel('No.of employees')
plt.show()

# %% [raw]
# after analyzing the graph, it can be concluded that this might not be the reason.

# %%
#looking at the time spent at the company by the employees that left
plt.figure(figsize=(10,9))
sns.countplot(df_left['time_spend_company']).get_figure().savefig('left time spent dist.png')
plt.title('distribution of time spent at the company by the employees that left')
plt.xlabel('time spent')
plt.ylabel('No.of employees')
plt.show()

# %%
#looking at the time spent at the company by the employees that exist
plt.figure(figsize=(10,9))
sns.countplot(df_exist['time_spend_company']).get_figure().savefig('exist time spent dist.png')
plt.title('distribution of time spent at the company by the employees that exist')
plt.xlabel('time spent')
plt.ylabel('No.of employees')
plt.show()

# %% [raw]
# on comparing both the graphs, this should not be a reson as the employee who are still working at the company have spent 10 while who left have not

# %%
#looking at the average monthly hours spent by the employees that left
plt.figure(figsize=(45,9))
sns.countplot(df_left['average_montly_hours']).get_figure().savefig('left av. hrs. dist.png')
plt.title('distribution of average monthly hours spent by the employees that left')
plt.xlabel('average monthly hours')
plt.ylabel('No.of employees')
plt.show()

# %%
#looking at the average monthly hours spent by the employees that exist
plt.figure(figsize=(45,9))
sns.countplot(df_exist['average_montly_hours']).get_figure().savefig('exist av. hrs. dist.png')
plt.title('distribution of average monthly hours spent by the employees that exist')
plt.xlabel('average monthly hours')
plt.ylabel('No.of employees')
plt.show()

# %% [raw]
# This is Clearly not the reason

# %%
#looking at the number of projects by the employees that left
plt.figure(figsize=(10,9))
sns.countplot(df_left['number_project']).get_figure().savefig('left projects dist.png')
plt.title('distribution of no. of projects by the employees that left')
plt.xlabel('no. of projects')
plt.ylabel('No.of employees')
plt.show()

# %%
#looking at the number of projects by the employees that exist
plt.figure(figsize=(10,9))
sns.countplot(df_exist['number_project']).get_figure().savefig('exist projects dist.png')
plt.title('distribution of no. of projects by the employees that exist')
plt.xlabel('no. of projects')
plt.ylabel('No.of employees')
plt.show()

# %% [raw]
# This can be a contributing factor.

# %%
#looking at the last evaluation of the employees that left
plt.figure(figsize=(20,9))
sns.countplot(df_left['last_evaluation']).get_figure().savefig('left last eval dist.png')
plt.title('distribution of last evaluation of the employees that left')
plt.xlabel('last evaluation')
plt.ylabel('No.of employees')
plt.show()

# %%
#looking at the last evaluation of the employees that exist
plt.figure(figsize=(20,9))
sns.countplot(df_exist['last_evaluation']).get_figure().savefig('exist last eval dist.png')
plt.title('distribution of last evaluation of the employees that exist')
plt.xlabel('last evaluation')
plt.ylabel('No.of employees')
plt.show()

# %% [raw]
# Might be a reason

# %%
#looking at the satisfaction level of the employees that left
plt.figure(figsize=(30,9))
sns.countplot(df_left['satisfaction_level']).get_figure().savefig('left satisfaction level dist.png')
plt.title('distribution of satisfaction level of the employees that left')
plt.xlabel('satisfaction level')
plt.ylabel('No.of employees')
plt.show()

# %%
#looking at the satisfaction level of the employees that exist
plt.figure(figsize=(30,9))
sns.countplot(df_exist['satisfaction_level']).get_figure().savefig('exist satisfaction level dist.png')
plt.title('distribution of satisfaction level of the employees that exist')
plt.xlabel('satisfaction level')
plt.ylabel('No.of employees')
plt.show()

# %% [raw]
# this can be a major factor in the leaing of the employeee

# %%
#lets compare if combination of the reasons mentioned can give an insight
plt.figure(figsize=(10,9))
sns.boxplot(x='number_project', y='satisfaction_level', hue='salary',data=df_left)
plt.title("Distribution of Satisfaction Level of Employees that left by no. of projects")
plt.xlabel('no. of projects')
plt.ylabel("Satisfaction Level")
# Out:
# Text(0, 0.5, 'Satisfaction Level')

# %%
plt.figure(figsize=(10,9))
sns.boxplot(x='number_project', y='satisfaction_level', hue='salary',data=df_exist)
plt.title("Distribution of Satisfaction Level of Existing Employees by no. of projects")
plt.xlabel('no. of projects')
plt.ylabel("Satisfaction Level")
# Out:
# Text(0, 0.5, 'Satisfaction Level')

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='salary', y='satisfaction_level', hue='number_project',data=df_left)
plt.title("Distribution of Satisfaction Level of Employees that left by salary")
plt.xlabel('salary')
plt.ylabel("Satisfaction Level")
# Out:
# Text(0, 0.5, 'Satisfaction Level')

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='salary', y='satisfaction_level', hue='number_project',data=df_exist)
plt.title("Distribution of Satisfaction Level of Existing Employees by salary")
plt.xlabel('salary')
plt.ylabel("Satisfaction Level")
# Out:
# Text(0, 0.5, 'Satisfaction Level')

# %%
df_exist['Left'] = 0

# %%
df_left['Left'] = 1

# %%
emp_data = pd.concat([df_left, df_exist], axis = 0)

# %% [markdown]
# ## Conclusion From Graphs

# %% [markdown]
# <p>Reasons for Employees quitting the company:<br>
#     <ol>
#         <li> People with large number of projects and more number of working hours( 3 project especially) are moe likely to quit</li>
#         <li>People with medium salary and have less years of experience are more likely to resign.</li>
#      </ol>
# </p>

# %% [markdown]
# ## Data Preparation

# %%
emp_data.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       1                0.38             0.53               2
# 1       2                0.80             0.86               5
# 2       3                0.11             0.88               7
# 3       4                0.72             0.87               5
# 4       5                0.37             0.52               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   157                   3              0
# 1                   262                   6              0
# 2                   272                   4              0
# 3                   223                   5              0
# 4                   159                   3              0
#
#    promotion_last_5years   dept  salary  Left
# 0                      0  sales     low     1
# 1                      0  sales  medium     1
# 2                      0  sales  medium     1
# ...

# %%
emp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14999 entries, 0 to 11427
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Emp ID                 14999 non-null  int64
#  1   satisfaction_level     14999 non-null  float64
#  2   last_evaluation        14999 non-null  float64
#  3   number_project         14999 non-null  int64
#  4   average_montly_hours   14999 non-null  int64
#  5   time_spend_company     14999 non-null  int64
#  6   Work_accident          14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
#  10  Left                   14999 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.4+ MB

# %% [markdown]
# <p> Here, columns dept and salary are categorical. So, we will convert them into binaries for ease of solving. </p>

# %%
columns = ['dept','salary']
dummies = pd.get_dummies(emp_data[columns], drop_first = True)
emp_data = pd.concat([emp_data, dummies], axis = 1)

# %%
emp_data.drop(columns, inplace = True, axis = 1)

# %%
emp_data.head()
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0       1                0.38             0.53               2
# 1       2                0.80             0.86               5
# 2       3                0.11             0.88               7
# 3       4                0.72             0.87               5
# 4       5                0.37             0.52               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   157                   3              0
# 1                   262                   6              0
# 2                   272                   4              0
# 3                   223                   5              0
# 4                   159                   3              0
#
#    promotion_last_5years  Left  dept_RandD  dept_accounting  dept_hr  \
# 0                      0     1           0                0        0
# 1                      0     1           0                0        0
# ...

# %% [markdown]
# ## Building the Model

# %% [markdown]
# <p>Since the target variable is categorical , i.e. , will the employee <b>leave</b> or <b>not leave</b> the company.</p>
# <p>We will use Logistic Regression</p>

# %%
X = emp_data.drop('Left', axis = 1)
y = emp_data['Left']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 123)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report
classification_report(y_test, pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.78      0.97      0.87      3430\n           1       0.58      0.13      0.21      1070\n\n    accuracy                           0.77      4500\n   macro avg       0.68      0.55      0.54      4500\nweighted avg       0.73      0.77      0.71      4500\n'

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, pred)
# Out:
# array([[3332,   98],
#        [ 935,  135]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.7704444444444445
